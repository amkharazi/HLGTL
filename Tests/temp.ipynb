# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path 
sys.path.append('..')

from Utils.TinyImageNet_loader import get_tinyimagenet_dataloaders
train_loader, val_loader, test_loader = get_tinyimagenet_dataloaders(data_dir='../datasets', image_size=192)

# %%
from Utils.TinyImageNet_loader import label_names_train, label_names_all

temp,t = label_names_train()
t[51]
# Out:
# ['n02415577',
#  'bighorn, bighorn sheep, cimarron, Rocky Mountain bighorn, Rocky Mountain sheep, Ovis canadensis']

# %%
tt = label_names_all()
tt['n02415577']
# Out:
# 'bighorn, bighorn sheep, cimarron, Rocky Mountain bighorn, Rocky Mountain sheep, Ovis canadensis'

# %%
val_loader.dataset[543][1]
# Out:
# 51

# %%
# import numpy as np
# np.unique(train_loader.dataset.targets)
# tt = train_loader.dataset[0][0]
# import matplotlib.pyplot as plt
# plt.imshow(tt.T)
