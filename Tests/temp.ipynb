# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

# %%
from Utils.Accuracy_measures import topk_accuracy
import torch

# %%
target = torch.tensor([0,4,3,2])
pred = torch.Tensor([[0.1,0.1,0.6,0.2,0.4], [0.4,0.4,0.5,0.1,0.8], [0.4,0.2,0.4,0,0], [0,0.1,0.1,0.7,0]])

# %%
_, topk_indices = pred.topk(k = 5, dim=1, largest=True, sorted=True)
target.view(-1, 1).expand_as(topk_indices)
correct = topk_indices.eq(target.view(-1, 1).expand_as(topk_indices)).sum()
(correct / pred.size(0)) * 100.0
# Out:
# tensor(100.)
