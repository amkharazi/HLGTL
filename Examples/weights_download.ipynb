# %% [markdown]
# # Add to the path

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

# %% [markdown]
# # Import Libraries

# %%
from Weights import download_resnet50_weights
from Weights import download_resnet101_weights 
from Weights import download_vgg19_weights

# %% [markdown]
# # Download ResNet 50 Weights
# Download the .pth files from official pytorch resnet50 model

# %%
download_resnet50_weights(save_dir = './weights')

# %%
# Or use the parser and run from console
# python Weights.py --model resnet50 --save_dir ./weights

# %% [markdown]
# # Download ResNet 101 Weights
#
# download the .pth files from official pytorch resnet101 model

# %%
download_resnet101_weights(save_dir = './weights')

# %%
# Or use the parser and run from console
# python Weights.py --model resnet101 --save_dir ./weights

# %% [markdown]
# # Download VGG 19 Weights
#
# download the .pth files from official pytorch vgg19 model

# %%
download_resnet101_weights(save_dir = './weights')

# %%
# Or use the parser and run from console
# python Weights.py --model vgg19 --save_dir ./weights

# %% [markdown]
# # Download all via parser

# %%
# Download all with default save directory (or use --save_dir if you need to change it)
# python Weights.py
